# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# !pip install talos
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: talos in /usr/local/lib/python3.7/dist-packages (1.3)
# Requirement already satisfied: wrangle in /usr/local/lib/python3.7/dist-packages (from talos) (0.7.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from talos) (1.3.5)
# Requirement already satisfied: tensorflow>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from talos) (2.8.0+zzzcolab20220506162203)
# Requirement already satisfied: kerasplotlib in /usr/local/lib/python3.7/dist-packages (from talos) (1.0)
# Requirement already satisfied: chances in /usr/local/lib/python3.7/dist-packages (from talos) (0.1.9)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from talos) (0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from talos) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from talos) (1.21.6)
# Requirement already satisfied: astetik in /usr/local/lib/python3.7/dist-packages (from talos) (1.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from talos) (4.64.0)
# Requirement already satisfied: statsmodels>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from talos) (0.13.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.11.0->talos) (21.3)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.11.0->talos) (1.4.1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.11.0->talos) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels>=0.11.0->talos) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->talos) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->talos) (2022.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.2->statsmodels>=0.11.0->talos) (1.15.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (57.4.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (3.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (1.46.1)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (0.5.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (1.1.2)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (1.0.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (3.17.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (3.3.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (4.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (1.1.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (2.8.0.dev2021122109)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (0.26.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.0.0->talos) (14.0.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0.0->talos) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.0.0->talos) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (0.4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->talos) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->talos) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->talos) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->talos) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.0.0->talos) (3.2.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from astetik->talos) (5.5.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from astetik->talos) (0.11.2)
# Requirement already satisfied: geonamescache in /usr/local/lib/python3.7/dist-packages (from astetik->talos) (1.3.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython->astetik->talos) (1.0.18)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->astetik->talos) (5.1.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->astetik->talos) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->astetik->talos) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->astetik->talos) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython->astetik->talos) (0.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->astetik->talos) (4.4.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->astetik->talos) (0.2.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from kerasplotlib->talos) (3.2.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->kerasplotlib->talos) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->kerasplotlib->talos) (1.4.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->astetik->talos) (0.7.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->talos) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->talos) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->talos) (3.1.0)

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import nltk
nltk.download('punkt')
from tensorflow.keras.optimizers import Adam,Nadam, SGD
import talos
# from keras.optimizers import SGD# - Works

#from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])



# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")

# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']
# Training data created
# Epoch 1/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.2998 - accuracy: 0.0851
# Epoch 2/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1212 - accuracy: 0.1277
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1302 - accuracy: 0.2128
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9538 - accuracy: 0.3191
# Epoch 5/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.8819 - accuracy: 0.4043
# Epoch 6/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.6828 - accuracy: 0.5319
# Epoch 7/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5719 - accuracy: 0.5532
# Epoch 8/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3572 - accuracy: 0.6383
# Epoch 9/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3902 - accuracy: 0.5106
# Epoch 10/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2808 - accuracy: 0.6596
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0876 - accuracy: 0.6596
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9197 - accuracy: 0.7234
# Epoch 13/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0005 - accuracy: 0.6383
# Epoch 14/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9463 - accuracy: 0.6809
# Epoch 15/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7955 - accuracy: 0.7234
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7918 - accuracy: 0.8085
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7174 - accuracy: 0.7234
# Epoch 18/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6263 - accuracy: 0.7447
# Epoch 19/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5822 - accuracy: 0.7872
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5571 - accuracy: 0.8298
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4519 - accuracy: 0.9362
# Epoch 22/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3677 - accuracy: 0.9149
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5108 - accuracy: 0.8298
# Epoch 24/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4125 - accuracy: 0.9149
# Epoch 25/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3231 - accuracy: 0.8936
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3192 - accuracy: 0.8936
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3766 - accuracy: 0.9149
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5048 - accuracy: 0.8723
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3042 - accuracy: 0.9362
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2700 - accuracy: 0.9574
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3460 - accuracy: 0.8936
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1668 - accuracy: 0.9787
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1858 - accuracy: 0.9574
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.9149
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1911 - accuracy: 0.9787
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2072 - accuracy: 0.9787
# Epoch 37/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2551 - accuracy: 0.9149
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3084 - accuracy: 0.9149
# Epoch 39/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1927 - accuracy: 0.9574
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1848 - accuracy: 1.0000
# Epoch 41/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2227 - accuracy: 0.9362
# Epoch 42/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0808 - accuracy: 0.9787
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1998 - accuracy: 0.9574
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1383 - accuracy: 1.0000
# Epoch 45/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 1.0000
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0816 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1181 - accuracy: 0.9787
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1154 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0864 - accuracy: 1.0000
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1228 - accuracy: 0.9574
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0464 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0792 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.9787
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1189 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0606 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1078 - accuracy: 0.9787
# Epoch 58/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2097 - accuracy: 0.9574
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1568 - accuracy: 0.9362
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0676 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0698 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1061 - accuracy: 0.9787
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0495 - accuracy: 0.9787
# Epoch 65/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0999 - accuracy: 0.9787
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1230 - accuracy: 0.9787
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 0.9787
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1436 - accuracy: 0.9574
# Epoch 69/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.9574
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1425 - accuracy: 0.9574
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1245 - accuracy: 0.9362
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 0.9787
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0524 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0738 - accuracy: 0.9574
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.9574
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0714 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0788 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1032 - accuracy: 0.9787
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0629 - accuracy: 0.9787
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 0.9787
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 0.9787
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0417 - accuracy: 0.9787
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0470 - accuracy: 0.9787
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0463 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9787
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0792 - accuracy: 0.9787
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 0.9787
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1019 - accuracy: 0.9787
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0313 - accuracy: 0.9787
# Epoch 144/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0844 - accuracy: 0.9574
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 0.9787
# Epoch 151/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0583 - accuracy: 0.9574
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0540 - accuracy: 0.9574
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 0.9787
# Epoch 162/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 0.9787
# Epoch 163/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 0.9787
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0982 - accuracy: 0.9787
# Epoch 168/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0875 - accuracy: 0.9574
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0599 - accuracy: 0.9787
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 0.9787
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0456 - accuracy: 0.9787
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0734 - accuracy: 0.9787
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0876 - accuracy: 0.9574
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 0.9787
# Epoch 180/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 0.9787
# Epoch 184/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0304 - accuracy: 0.9787
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1018 - accuracy: 0.9574
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9787
# Epoch 200/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 1.0000
# model created
